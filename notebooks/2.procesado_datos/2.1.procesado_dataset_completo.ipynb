# %% [markdown]
# Primero que nada vamos a importar pandas, una librería que se usa en el contexto de la manipulación de datos, en específico datos tabulares como lo pueden ser hojas de cálculo, base de datos o en mi caso que son archivos .CSV, esto ya que necesitamos unificar distintos tipos de archivos .CSV que vienen de diferentes fuentes

# %%
import pandas as pd

# %% [markdown]
# Ahora vamos a importar el df1 que es el principal, cabe recalcar que la columna de comuna, no fue extraída mediante scraping, esta fue mediante la descarga de un archivo Shapely y luego mediante librerías como, shapely, geopandas, matplotlib y folium se pudieron obtener los polígonos de las comunas a partir de las coordenadas, además esto es bastante conveniente tomando en cuenta que sirve para todo el territorio de Chile, no solo la región metropolitana

# %%
df1 = pd.read_csv("../../data/interim/propiedades_con_comuna.csv", encoding="utf-8", delimiter=",")
df1.head()
# Out:
#         precio  banos  dormitorios  superficie_total  superficie_construida  \
# 0  322633576.0    3.0          5.0             404.0                  275.0
# 1  124089837.0    3.0          3.0             102.0                   27.0
# 2  157180460.0    2.0          3.0             190.0                  127.0
# 3  133544301.0    2.0          5.0             146.0                   61.0
# 4  117786861.0    2.0          3.0             145.0                   82.0
#
#    estacionamiento    latitud   longitud        comuna
# 0              1.0 -33.345468 -70.678398    Huechuraba
# 1              1.0 -33.563160 -70.776609         Maipú
# 2              1.0 -33.563025 -70.559425   Puente Alto
# 3              1.0 -33.641678 -70.689872  San Bernardo
# 4              1.0 -33.613778 -70.887450      Peñaflor

# %% [markdown]
# En el df1 aunque existan valores nulos o NaN, no los imputare, esto debido a que intenté usar KNN para imputar valores NaN y el rendimiento de los modelos disminuyó, y es que a veces es mejor no imputar datos y simplemente eliminarlos, cosa que en el caso del df2, no sucedió

# %%
df1.isna().sum()
# Out:
# precio                   11
# banos                    47
# dormitorios              38
# superficie_total         59
# superficie_construida    83
# estacionamiento          30
# latitud                  13
# longitud                 13
# comuna                   20
# dtype: int64

# %% [markdown]
# Por el lado del df2, este fue extraído mediante scraping de datos de la mapoteca de la Biblioteca del Congreso Nacional de Chile, el cual tiene datos de todas las comunas de Chile, incluyendo datos, demográficos, sociales, salud, económicos, seguridad, educacionales y electorales, esto debido a que se extrajeron datos de 52 comunas, y cada comuna tenía 29 variables, por lo cual mediante scraping se hace la tarea mucho más amena y eficiente

# %%
df2 = pd.read_csv("../../data/external/scraped/datos_comunas_extraidos.csv", encoding="utf-8", delimiter=",")
df2.head()
# Out:
#             Comuna  Población 2024  Índice Masculinidad 2024  \
# 0            Alhué            7768                      98.9
# 1             Buin          116969                      93.6
# 2  Calera de Tango           25491                      97.9
# 3        Cerrillos           85041                      94.0
# 4      Cerro Navia          127250                      96.0
#
#    Grupo_Etario_0_a_14_2024_(%)  Grupo_Etario_15_a_29_2024_(%)  \
# 0                          20.7                           20.0
# 1                          21.3                           19.6
# 2                          18.0                           21.1
# 3                          18.7                           21.7
# 4                          17.6                           21.6
#
#    Grupo_Etario_30_a_44_2024_(%)  Grupo_Etario_45_a_64_2024_(%)  \
# 0                           23.3                           23.0
# 1                           26.5                           22.2
# 2                           20.7                           26.7
# 3                           22.9                           23.7
# 4                           20.6                           25.4
#
#    Grupo_Etario_65_o_mas_2024_(%)  IDD 2024  IAM 2024  ...  \
# 0                            13.0      51.0      62.8  ...
# 1                            10.4      46.4      48.7  ...
# 2                            13.5      46.0      74.8  ...
# 3                            13.0      46.3      69.7  ...
# 4                            14.7      47.7      83.8  ...
#
#    Trabajadores_Enseñanza_2023  Trabajadores_Salud_2023  \
# 0                            0                        5
# 1                         1614                     1788
# 2                          492                       70
# 3                          947                     1179
# 4                         1312                     4044
#
#    Trabajadores_Artísticas_Entretenimiento_2023  \
# 0                                             0
# 1                                           602
# 2                                            10
# 3                                            39
# 4                                            25
#
#    Trabajadores_Otras_Actividades_2023  Trabajadores_Hogares_Empleadores_2023  \
# 0                                   11                                      0
# 1                                  433                                      0
# 2                                  778                                      0
# 3                                  645                                      0
# 4                                 1210                                      0
#
#    Trabajadores_Organizaciones_Extraterritoriales_2023  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Trabajadores_Sin_Información_2023  \
# 0                                  0
# 1                                 10
# 2                                  4
# 3                                 31
# 4                                  1
#
#    Disponibilidad_Presupuestaria_por_Habitante_2023_(M$)  \
# 0                                               2724
# 1                                                341
# 2                                                487
# 3                                                335
# 4                                                286
#
#    Delitos Mayor Connotación Social 2023 (c/100.000 hab)  \
# 0                                             1947.6
# 1                                             1982.5
# 2                                             2044.1
# 3                                             3434.2
# 4                                             3053.7
#
#    Violencia Intrafamiliar 2023 (c/100.000 hab)
# 0                                         929.2
# 1                                         459.4
# 2                                         548.2
# 3                                         682.0
# 4                                         675.3
#
# [5 rows x 135 columns]

# %%
guiones_total = (df2 == "-").sum().sum()
guiones_mortalidad = (df2['Mortalidad Infantil 2022 (c/1.000 nac.vivos)'] == "-").sum()

print(f'Total de NaN: {guiones_total}\n'
      f'NaN en mortalidad infantil: {guiones_mortalidad}')
# Out:
# Total de NaN: 4
# NaN en mortalidad infantil: 4

# %% [markdown]
# Los modelos de machine learning son muy útiles cuando se trata de imputación de datos, y es que hay que aprovechar que disponemos de una amplia gama de variables que podemos usar para apalancarnos y usar modelos como random forest y no perder datos valiosos dentro de nuestro dataset, hay muchas herramientas que se pueden usar para imputar datos, como media, mediana, o moda, pero también se pueden usar métodos estadísticos, generalmente se usa k-Nearest Neighbors para la imputación de datos, pero yo creo que para este caso con 4 comunas sin datos para la columna de mortalidad infantil, debido a la alta cantidad de variables random forest es mejor método para la imputación para este caso

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor

target = 'Mortalidad Infantil 2022 (c/1.000 nac.vivos)'
df2[target] = df2[target].replace('-', np.nan)
df2[target] = pd.to_numeric(df2[target], errors='coerce')
complete_data = df2.dropna(subset=[target])

predictores = [
    'Pobreza por ingresos 2022 (%)',
    'Pobreza multidimensional 2022 (%)',
    'Mortalidad General 2022 (c/1.000 hab)',
    'Carentes servicios básicos 2025 (%)',
    'Hogares hacinados 2025 (%)',
    'Natalidad 2022',
    'Fecundidad 2022',
    'Cantidad de: Centro de Salud Familiar (CESFAM) 2025',
    'Cantidad de: Hospital 2025',
    'Grupo_Etario_0_a_14_2024_(%)',
    'Disponibilidad_Presupuestaria_por_Habitante_2023_(M$)',
    'SIMCE 4to Básico Lectura 2022'
]

# %%
X_train = complete_data[predictores]
y_train = complete_data[target]

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

missing_mask = df2[target].isnull()
X_missing = df2.loc[missing_mask, predictores]
predicted_values = model.predict(X_missing)

df2.loc[missing_mask, target] = np.round(predicted_values, 1)

# %% [markdown]
# Ahora lo que vamos a hacer es incorporar más variables relacionadas a las características de las casas en cada comuna según la base de datos de CASEN 2022 para luego unificar toda esta

# %%
df3 = pd.read_csv("../../data/interim/caracteristicas_vivienda_rm_casen2022.csv", encoding="utf-8", delimiter=",")
df3 = df3.drop('codigo_comuna', axis=1)
df3 = df3.rename(columns={'nombre_comuna': 'comuna'})
df3.head()
# Out:
#         comuna  n_registros  pct_casa  pct_departamento  pct_casa_depto  \
# 0     Santiago         1793      0.78              2.79            3.57
# 1    Cerrillos          401     28.93             40.40           69.33
# 2  Cerro Navia          555     39.28             26.13           65.41
# 3     Conchalí          560     15.89             56.96           72.86
# 4    El Bosque          810     19.26             47.28           66.54
#
#    pct_vivienda_precaria  pct_paredes_solidas  pct_techo_solido  \
# 0                  75.46                87.62             96.04
# 1                  18.45                83.79             95.51
# 2                   7.03                78.02             97.48
# 3                  17.32                78.75             84.11
# 4                  15.80                85.43             96.30
#
#    pct_piso_bueno  pct_agua_red_publica  pct_wc_bueno  pct_cocina_moderna  \
# 0           95.37                 68.93         73.73               94.70
# 1           95.26                 71.07         36.91               87.28
# 2           89.01                 68.65         11.89               94.41
# 3           93.04                 41.61         16.25               76.79
# 4           93.83                 76.79         14.69               94.07
#
#    pct_propia_total  pct_arrendada  ingreso_promedio  ingreso_mediana  \
# 0             18.96           0.11         791945.92         600000.0
# 1             51.37           3.74         528548.10         450000.0
# 2             61.98           1.98         446483.01         400000.0
# 3             46.96           0.36         456803.06         400000.0
# 4             57.78           0.99         395604.34         350000.0
#
#    indice_calidad_materiales  indice_servicios_basicos  \
# 0                      93.01                     79.12
# 1                      91.52                     65.09
# 2                      88.17                     58.32
# 3                      85.30                     44.88
# 4                      91.85                     61.85
#
#    indice_calidad_vivienda_general
# 0                            58.57
# 1                            75.31
# 2                            70.63
# 3                            67.68
# 4                            73.42

# %% [markdown]
# Luego de tener los 2 datasets, lo que hice fue hacerles un "merge" que consiste en unir estos 2 datasets, utilizando la columna ['comuna'] como una especie de llave o "key" que alimenta con más variables cada fila

# %%
df1['comuna'] = df1['comuna'].str.strip().str.lower()
df2['Comuna'] = df2['Comuna'].str.strip().str.lower()
df3['comuna'] = df3['comuna'].str.strip().str.lower()

df2.columns = df2.columns.str.lower()

df = pd.merge(df1, df2, on='comuna', how='left')
df = pd.merge(df, df3, on='comuna', how='left')

df.head()
# Out:
#         precio  banos  dormitorios  superficie_total  superficie_construida  \
# 0  322633576.0    3.0          5.0             404.0                  275.0
# 1  124089837.0    3.0          3.0             102.0                   27.0
# 2  157180460.0    2.0          3.0             190.0                  127.0
# 3  133544301.0    2.0          5.0             146.0                   61.0
# 4  117786861.0    2.0          3.0             145.0                   82.0
#
#    estacionamiento    latitud   longitud        comuna  población 2024  ...  \
# 0              1.0 -33.345468 -70.678398    huechuraba        101808.0  ...
# 1              1.0 -33.563160 -70.776609         maipú        503635.0  ...
# 2              1.0 -33.563025 -70.559425   puente alto        568086.0  ...
# 3              1.0 -33.641678 -70.689872  san bernardo        306371.0  ...
# 4              1.0 -33.613778 -70.887450      peñaflor         94402.0  ...
#
#    pct_agua_red_publica  pct_wc_bueno  pct_cocina_moderna  pct_propia_total  \
# 0                 61.78         32.43               89.86             64.31
# 1                 76.69         38.93               92.76             70.40
# 2                 72.70         34.05               90.62             69.71
# 3                 70.58         26.52               90.21             58.31
# 4                 72.05         25.70               89.12             65.85
#
#    pct_arrendada  ingreso_promedio  ingreso_mediana  \
# 0           0.00         720051.66         402500.0
# 1           0.80         601743.03         450000.0
# 2           0.18         538232.86         400000.0
# 3           1.16         488733.18         400000.0
# 4           0.19         591753.35         400000.0
#
#    indice_calidad_materiales  indice_servicios_basicos  \
# 0                      86.47                     61.35
# 1                      94.91                     69.46
# 2                      93.75                     65.79
# 3                      89.94                     62.44
# 4                      84.18                     62.29
#
#    indice_calidad_vivienda_general
# 0                            74.64
# 1                            78.23
# 2                            78.18
# 3                            76.41
# 4                            77.28
#
# [5 rows x 161 columns]

# %% [markdown]
# Luego lo que vamos a hacer es crear un archivo CSV a partir del df, y vamos a importar las coordenadas de todos los hospitales y estaciones de metro, estos al igual que el caso de los datos de las comunas, son extraídos a partir de archivos Shapely mediante python y respectivas librerías ya mencionadas, estas coordenadas de hospitales y metros son usadas para luego calcular la distancia lineal entre las casas y el hospital y metro más cercano

# %%
df_hospitales = pd.read_csv("../../data/interim/coordenadas_hospitales_publicos_rm.csv", encoding="utf-8", delimiter=",")
df_metro = pd.read_csv("../../data/interim/coordenadas_estaciones_metro.csv", encoding="utf-8", delimiter=",")

# %%
df.head()
# Out:
#         precio  banos  dormitorios  superficie_total  superficie_construida  \
# 0  322633576.0    3.0          5.0             404.0                  275.0
# 1  124089837.0    3.0          3.0             102.0                   27.0
# 2  157180460.0    2.0          3.0             190.0                  127.0
# 3  133544301.0    2.0          5.0             146.0                   61.0
# 4  117786861.0    2.0          3.0             145.0                   82.0
#
#    estacionamiento    latitud   longitud        comuna  población 2024  ...  \
# 0              1.0 -33.345468 -70.678398    huechuraba        101808.0  ...
# 1              1.0 -33.563160 -70.776609         maipú        503635.0  ...
# 2              1.0 -33.563025 -70.559425   puente alto        568086.0  ...
# 3              1.0 -33.641678 -70.689872  san bernardo        306371.0  ...
# 4              1.0 -33.613778 -70.887450      peñaflor         94402.0  ...
#
#    pct_agua_red_publica  pct_wc_bueno  pct_cocina_moderna  pct_propia_total  \
# 0                 61.78         32.43               89.86             64.31
# 1                 76.69         38.93               92.76             70.40
# 2                 72.70         34.05               90.62             69.71
# 3                 70.58         26.52               90.21             58.31
# 4                 72.05         25.70               89.12             65.85
#
#    pct_arrendada  ingreso_promedio  ingreso_mediana  \
# 0           0.00         720051.66         402500.0
# 1           0.80         601743.03         450000.0
# 2           0.18         538232.86         400000.0
# 3           1.16         488733.18         400000.0
# 4           0.19         591753.35         400000.0
#
#    indice_calidad_materiales  indice_servicios_basicos  \
# 0                      86.47                     61.35
# 1                      94.91                     69.46
# 2                      93.75                     65.79
# 3                      89.94                     62.44
# 4                      84.18                     62.29
#
#    indice_calidad_vivienda_general
# 0                            74.64
# 1                            78.23
# 2                            78.18
# 3                            76.41
# 4                            77.28
#
# [5 rows x 161 columns]

# %% [markdown]
# La siguiente celda lo que hace es calcular la distancia entre la coordenada de la casa, y la coordenada del hospital más cercano y luego crear una columna llamada 'distancia_hospital' y agregarla al data frame

# %%
prop_coords = df[['latitud', 'longitud']].to_numpy()
hospital_coords = df_hospitales[['latitud hospital', 'longitud hospital']].to_numpy()

prop_coords_rad = np.radians(prop_coords)
hospital_coords_rad = np.radians(hospital_coords)

def haversine_vectorized(coord1, coord2):
    R = 6371000 

    lat1 = coord1[:, 0][:, np.newaxis]
    lon1 = coord1[:, 1][:, np.newaxis]
    lat2 = coord2[:, 0]
    lon2 = coord2[:, 1]

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))

    return R * c  

dist_matrix = haversine_vectorized(prop_coords_rad, hospital_coords_rad)
df['distancia_hospital'] = dist_matrix.min(axis=1)
df
# Out:
#            precio  banos  dormitorios  superficie_total  \
# 0     322633576.0    3.0          5.0             404.0
# 1     124089837.0    3.0          3.0             102.0
# 2     157180460.0    2.0          3.0             190.0
# 3     133544301.0    2.0          5.0             146.0
# 4     117786861.0    2.0          3.0             145.0
# ...           ...    ...          ...               ...
# 5965  742425000.0    5.0          5.0             370.0
# 5966   69709800.0    1.0          2.0              88.0
# 5967   75000000.0    2.0          4.0             100.0
# 5968  859650000.0    5.0          6.0            1000.0
# 5969  349721250.0    4.0          5.0            1230.0
#
#       superficie_construida  estacionamiento    latitud   longitud  \
# 0                     275.0              1.0 -33.345468 -70.678398
# 1                      27.0              1.0 -33.563160 -70.776609
# 2                     127.0              1.0 -33.563025 -70.559425
# 3                      61.0              1.0 -33.641678 -70.689872
# 4                      82.0              1.0 -33.613778 -70.887450
# ...                     ...              ...        ...        ...
# 5965                  230.0              0.0 -33.421135 -70.553193
# 5966                   70.0              0.0 -33.513907 -70.783665
# 5967                   80.0              0.0 -33.416357 -70.765798
# 5968                  320.0              0.0 -34.147102 -71.462988
# 5969                  192.0              1.0 -33.599666 -70.869676
#
#             comuna  población 2024  ...  pct_wc_bueno  pct_cocina_moderna  \
# 0       huechuraba        101808.0  ...         32.43               89.86
# 1            maipú        503635.0  ...         38.93               92.76
# 2      puente alto        568086.0  ...         34.05               90.62
# 3     san bernardo        306371.0  ...         26.52               90.21
# 4         peñaflor         94402.0  ...         25.70               89.12
# ...            ...             ...  ...           ...                 ...
# 5965    las condes        296134.0  ...         88.15               98.33
# 5966         maipú        503635.0  ...         38.93               92.76
# 5967   cerro navia        127250.0  ...         11.89               94.41
# 5968           NaN             NaN  ...           NaN                 NaN
# 5969      peñaflor         94402.0  ...         25.70               89.12
#
#       pct_propia_total  pct_arrendada  ingreso_promedio  ingreso_mediana  \
# 0                64.31           0.00         720051.66         402500.0
# 1                70.40           0.80         601743.03         450000.0
# 2                69.71           0.18         538232.86         400000.0
# 3                58.31           1.16         488733.18         400000.0
# 4                65.85           0.19         591753.35         400000.0
# ...                ...            ...               ...              ...
# 5965             56.67           0.49        1806493.23        1050000.0
# 5966             70.40           0.80         601743.03         450000.0
# 5967             61.98           1.98         446483.01         400000.0
# 5968               NaN            NaN               NaN              NaN
# 5969             65.85           0.19         591753.35         400000.0
#
#       indice_calidad_materiales  indice_servicios_basicos  \
# 0                         86.47                     61.35
# 1                         94.91                     69.46
# 2                         93.75                     65.79
# 3                         89.94                     62.44
# 4                         84.18                     62.29
# ...                         ...                       ...
# 5965                      97.94                     92.51
# 5966                      94.91                     69.46
# 5967                      88.17                     58.32
# 5968                        NaN                       NaN
# 5969                      84.18                     62.29
#
#       indice_calidad_vivienda_general  distancia_hospital
# 0                               74.64         8064.787023
# 1                               78.23         6113.888686
# 2                               78.18          845.094730
# 3                               76.41         5475.616211
# 4                               77.28         1600.028166
# ...                               ...                 ...
# 5965                            77.68         4638.577959
# 5966                            78.23         1078.534716
# 5967                            70.63         2381.181842
# 5968                              NaN        55220.407889
# 5969                            77.28         3391.329367
#
# [5970 rows x 162 columns]

# %% [markdown]
# La siguiente celda lo que hace es lo mismo que la celda anterior, pero la diferencia es que aquí nosotros calculamos la distancia al punto de coordenadas de estación de metro más cercano y creamos la columna llamada 'distancia_metro' que luego es agregada al dataframe, hay que tomar en cuenta que para poder saber la distancia lineal en metros, se requiere del radio de la tierra en metros definido en la variable R que aparece en la celda de abajo

# %%
prop_coords = df[['latitud', 'longitud']].to_numpy()
metro_coords = df_metro[['latitud_estacion_metro', 'longitud_estacion_metro']].to_numpy()

prop_coords_rad = np.radians(prop_coords)
metro_coords_rad = np.radians(metro_coords)

def haversine_vectorized(coord1, coord2):
    R = 6371000  

    lat1 = coord1[:, 0][:, np.newaxis]
    lon1 = coord1[:, 1][:, np.newaxis]
    lat2 = coord2[:, 0]
    lon2 = coord2[:, 1]

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))

    return R * c

dist_matrix = haversine_vectorized(prop_coords_rad, metro_coords_rad)

df['distancia_metro'] = dist_matrix.min(axis=1)

df
# Out:
#            precio  banos  dormitorios  superficie_total  \
# 0     322633576.0    3.0          5.0             404.0
# 1     124089837.0    3.0          3.0             102.0
# 2     157180460.0    2.0          3.0             190.0
# 3     133544301.0    2.0          5.0             146.0
# 4     117786861.0    2.0          3.0             145.0
# ...           ...    ...          ...               ...
# 5965  742425000.0    5.0          5.0             370.0
# 5966   69709800.0    1.0          2.0              88.0
# 5967   75000000.0    2.0          4.0             100.0
# 5968  859650000.0    5.0          6.0            1000.0
# 5969  349721250.0    4.0          5.0            1230.0
#
#       superficie_construida  estacionamiento    latitud   longitud  \
# 0                     275.0              1.0 -33.345468 -70.678398
# 1                      27.0              1.0 -33.563160 -70.776609
# 2                     127.0              1.0 -33.563025 -70.559425
# 3                      61.0              1.0 -33.641678 -70.689872
# 4                      82.0              1.0 -33.613778 -70.887450
# ...                     ...              ...        ...        ...
# 5965                  230.0              0.0 -33.421135 -70.553193
# 5966                   70.0              0.0 -33.513907 -70.783665
# 5967                   80.0              0.0 -33.416357 -70.765798
# 5968                  320.0              0.0 -34.147102 -71.462988
# 5969                  192.0              1.0 -33.599666 -70.869676
#
#             comuna  población 2024  ...  pct_cocina_moderna  pct_propia_total  \
# 0       huechuraba        101808.0  ...               89.86             64.31
# 1            maipú        503635.0  ...               92.76             70.40
# 2      puente alto        568086.0  ...               90.62             69.71
# 3     san bernardo        306371.0  ...               90.21             58.31
# 4         peñaflor         94402.0  ...               89.12             65.85
# ...            ...             ...  ...                 ...               ...
# 5965    las condes        296134.0  ...               98.33             56.67
# 5966         maipú        503635.0  ...               92.76             70.40
# 5967   cerro navia        127250.0  ...               94.41             61.98
# 5968           NaN             NaN  ...                 NaN               NaN
# 5969      peñaflor         94402.0  ...               89.12             65.85
#
#       pct_arrendada  ingreso_promedio  ingreso_mediana  \
# 0              0.00         720051.66         402500.0
# 1              0.80         601743.03         450000.0
# 2              0.18         538232.86         400000.0
# 3              1.16         488733.18         400000.0
# 4              0.19         591753.35         400000.0
# ...             ...               ...              ...
# 5965           0.49        1806493.23        1050000.0
# 5966           0.80         601743.03         450000.0
# 5967           1.98         446483.01         400000.0
# 5968            NaN               NaN              NaN
# 5969           0.19         591753.35         400000.0
#
#       indice_calidad_materiales  indice_servicios_basicos  \
# 0                         86.47                     61.35
# 1                         94.91                     69.46
# 2                         93.75                     65.79
# 3                         89.94                     62.44
# 4                         84.18                     62.29
# ...                         ...                       ...
# 5965                      97.94                     92.51
# 5966                      94.91                     69.46
# 5967                      88.17                     58.32
# 5968                        NaN                       NaN
# 5969                      84.18                     62.29
#
#       indice_calidad_vivienda_general  distancia_hospital  distancia_metro
# 0                               74.64         8064.787023      2554.229150
# 1                               78.23         6113.888686      6127.575990
# 2                               78.18          845.094730      2324.734493
# 3                               76.41         5475.616211     11151.846959
# 4                               77.28         1600.028166     16662.321199
# ...                               ...                 ...              ...
# 5965                            77.68         4638.577959      1526.624955
# 5966                            78.23         1078.534716      2485.915755
# 5967                            70.63         2381.181842      3924.559734
# 5968                              NaN        55220.407889     96236.455245
# 5969                            77.28         3391.329367     14388.235978
#
# [5970 rows x 163 columns]

# %%
df.to_csv("../../data/interim/datos_variables_completas.csv", index=False)

# %%
print(df.columns.tolist())
# Out:
# ['precio', 'banos', 'dormitorios', 'superficie_total', 'superficie_construida', 'estacionamiento', 'latitud', 'longitud', 'comuna', 'población 2024', 'índice masculinidad 2024', 'grupo_etario_0_a_14_2024_(%)', 'grupo_etario_15_a_29_2024_(%)', 'grupo_etario_30_a_44_2024_(%)', 'grupo_etario_45_a_64_2024_(%)', 'grupo_etario_65_o_mas_2024_(%)', 'idd 2024', 'iam 2024', 'pobreza por ingresos 2022 (%)', 'pobreza multidimensional 2022 (%)', 'pueblos indígenas 2025 (%)', 'extranjeros 2025 (%)', 'carentes servicios básicos 2025 (%)', 'hogares hacinados 2025 (%)', 'cantidad de: atención remota 2025', 'cantidad de: centro comunitario de salud familiar (cecosf) 2025', 'cantidad de: centro comunitario de salud mental  (cosam) 2025', 'cantidad de: centro corporación para la nutrición infantil (conin) 2025', 'cantidad de: centro de apoyo comunitario para personas con demencia 2025', 'cantidad de: centro diagnóstico terapéutico y tratamiento privado (cdt) 2025', 'cantidad de: centro de diálisis 2025', 'cantidad de: centro de especialidad 2025', 'cantidad de: centro de referencia de salud (crs) 2025', 'cantidad de: centro de regulación médica de las urgencias (samu) 2025', 'cantidad de: centro de rehabilitación 2025', 'cantidad de: centro de salud de atención cerrada para personas privadas de libertad 2025', 'cantidad de: centro de salud familiar (cesfam) 2025', 'cantidad de: centro de salud mental 2025', 'cantidad de: centro de salud privado 2025', 'cantidad de: centro de salud público 2025', 'cantidad de: centro de tratamiento de adicciones (cta) 2025', 'cantidad de: clínica 2025', 'cantidad de: clínica dental 2025', 'cantidad de: clínica dental móvil 2025', 'cantidad de: consultorio general rural (cgr) 2025', 'cantidad de: consultorio general urbano  (cgu) 2025', 'cantidad de: dirección servicio de salud 2025', 'cantidad de: dispositivo incorporado por crisis sanitaria 2025', 'cantidad de: estación médica rural (emr) 2025', 'cantidad de: hospital 2025', 'cantidad de: hospital de dia adulto 2025', 'cantidad de: hospital de día infanto adolescente 2025', 'cantidad de: laboratorio clínico 2025', 'cantidad de: oficina sanitaria 2025', 'cantidad de: policlínico funcionarios (minería) 2025', 'cantidad de: posta de salud rural (psr) 2025', 'cantidad de: programa de reparación y atención integral de salud (prais) 2025', 'cantidad de: puesto de atención médica especializado (pame) incorporado por crisis sanitaria 2025', 'cantidad de: sala  externa de toma de muestras (setm) 2025', 'cantidad de: salud ambiental 2025', 'cantidad de: servicio de atención primaria de urgencia (sapu) 2025', 'cantidad de: servicio de atención primaria de urgencia de alta resolutividad (sar) 2025', 'cantidad de: servicio de urgencia rural (sur) 2025', 'cantidad de: unidad de atención primaria oftalmológica (uapo) 2025', 'cantidad de: unidad de procedimientos móvil 2025', 'cantidad de: unidad de salud funcionarios 2025', 'cantidad de: vacunatorio 2025', 'fecundidad 2022', 'natalidad 2022', 'mortalidad general 2022 (c/1.000 hab)', 'mortalidad infantil 2022 (c/1.000 nac.vivos)', 'matrícula municipal 2024', 'matrícula subvencionada 2024', 'matrícula particular pagado 2024', 'matrícula corporación admin delegada 2024', 'matrícula servicio local educación 2024', 'matrícula_educación_parvularia_2024', 'matrícula_enseñanza_básica_niños_2024', 'matrícula_educación_básica_adultos_2024', 'matrícula_educación_especial_2024', 'matrícula_enseñanza_media_humanístico-científica_jóvenes_2024', 'matrícula_educación_media_humanístico-científica_adultos_2024', 'matrícula_enseñanza_media_técnico_profesional_y_artística_jóvenes_2024', 'matrícula_educación_media_técnico_profesional_y_artística_adultos_2024', 'simce 4to básico lectura 2022', 'simce 4to básico matemáticas 2022', 'empresas_micro_2023', 'empresas_pequeña_2023', 'empresas_mediana_2023', 'empresas_grande_2023', 'empresas_sin_ventas_sin_información_2023', 'trabajadores_micro_2023', 'trabajadores_pequeña_2023', 'trabajadores_mediana_2023 ...
